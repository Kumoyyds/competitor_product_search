# %% [markdown]
# # prepare the testfiles for iteration

# %%
import pandas as pd

# %%
temp_data_root = "./0_Data/"

# %%
df = pd.read_excel(temp_data_root + "tesco_algo.xlsx")

# %%
df
# Out:
#       Platforms  item_sku_id_new  \
# 0        JOUBUY         10043616
# 1        JOUBUY         10043155
# 2        JOUBUY         10043173
# 3        JOUBUY         10043171
# 4        JOUBUY         10043650
# ...         ...              ...
# 18637    JOUBUY         10012103
# 18638    JOUBUY         10012050
# 18639    JOUBUY         10011986
# 18640    JOUBUY         10012323
# 18641    JOUBUY         10012311
#
#                                     item_sku_name_en_new  \
# 0        ONE LIVING GINGER SUGAR FREE KOMBUCHA 4 X 250ML
# 1                  OLD SESSION HEN 10 X 440ML (ABV 3.4%)
# 2      NORTH BREWING ATLANTIS SESSION IPA 4 X 330ML (...
# 3                MAGIC ROCK SAUCERY 4 X 330ML (ABV 3.9%)
# 4               KOPPARBERG VARIETY 12 X 330ML (ABV 3.4%)
# ...                                                  ...
# 18637       Schwarzkopf got2b i Styler Texture Clay 75ml
# 18638  Schwarzkopf got2b Glued Water Resistant Spikin...
# ...
